# %%
#import plotly
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv('TelcoCustomerChurn.csv')
dataset.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
(dataset.isnull() | dataset.empty | dataset.isna()).sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
X = dataset.drop(['Churn'], axis=1)
y = dataset['Churn']

# %%
y.value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
# Show pie plot (Approach 1)
y.value_counts().plot.pie(autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='Churn'>

# %% [markdown]
# ### **Random Undersampling**
#
# ``'not minority'`` = resample all classes but the minority class

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(sampling_strategy=1) # Numerical value
# rus = RandomUnderSampler(sampling_strategy="not minority") # String
X_res, y_res = rus.fit_resample(X, y)

ax = y_res.value_counts().plot.pie(autopct='%.2f')
_ = ax.set_title("Under-sampling")

# %%
X_res
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     4359-INNWN  Female              0      No         No      17
# 1     6497-TILVL  Female              0     Yes        Yes       7
# 2     9152-AMKAK    Male              0      No         No       6
# 3     8909-BOLNL    Male              0      No         No       3
# 4     6421-SZVEM  Female              0     Yes        Yes      28
# ...          ...     ...            ...     ...        ...     ...
# 3733  1699-HPSBG    Male              0      No         No      12
# 3734  8775-CEBBJ  Female              0      No         No       9
# 3735  6894-LFHLY    Male              1      No         No       1
# 3736  0639-TSIQW  Female              0      No         No      67
# 3737  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  \
# 0             Yes            No              No  No internet service
# 1             Yes            No             DSL                  Yes
# 2             Yes            No             DSL                  Yes
# 3             Yes            No              No  No internet service
# 4             Yes            No     Fiber optic                  Yes
# ...           ...           ...             ...                  ...
# 3733          Yes            No             DSL                   No
# 3734          Yes            No             DSL                   No
# 3735          Yes           Yes     Fiber optic                   No
# 3736          Yes           Yes     Fiber optic                  Yes
# 3737          Yes           Yes     Fiber optic                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 0     No internet service  No internet service  No internet service
# 1                      No                   No                   No
# 2                      No                  Yes                  Yes
# 3     No internet service  No internet service  No internet service
# 4                      No                   No                   No
# ...                   ...                  ...                  ...
# 3733                   No                   No                  Yes
# 3734                   No                   No                   No
# 3735                   No                   No                   No
# 3736                  Yes                  Yes                   No
# 3737                   No                   No                   No
#
#               StreamingTV      StreamingMovies        Contract  \
# 0     No internet service  No internet service        One year
# 1                      No                   No  Month-to-month
# 2                     Yes                  Yes        Two year
# 3     No internet service  No internet service        One year
# 4                      No                  Yes        One year
# ...                   ...                  ...             ...
# 3733                  Yes                   No        One year
# 3734                   No                   No  Month-to-month
# 3735                   No                   No  Month-to-month
# 3736                  Yes                   No  Month-to-month
# 3737                   No                   No  Month-to-month
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0                  No    Credit card (automatic)           20.05        337.9
# 1                  No               Mailed check           50.70       350.35
# 2                 Yes               Mailed check           80.25        493.4
# 3                  No               Mailed check           21.20        52.05
# 4                 Yes  Bank transfer (automatic)           82.85       2320.8
# ...               ...                        ...             ...          ...
# 3733              Yes           Electronic check           59.80        727.8
# 3734              Yes  Bank transfer (automatic)           44.20       403.35
# 3735              Yes           Electronic check           75.75        75.75
# 3736              Yes    Credit card (automatic)          102.95      6886.25
# 3737              Yes               Mailed check           74.40        306.6
#
# [3738 rows x 20 columns]

# %%
y_res
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 3733    Yes
# 3734    Yes
# 3735    Yes
# 3736    Yes
# 3737    Yes
# Name: Churn, Length: 3738, dtype: object

# %% [markdown]
# ### **Random Oversampling**
#
# ``"not majority"`` = resample all classes but the majority class

# %%
from imblearn.over_sampling import RandomOverSampler

#ros = RandomOverSampler(sampling_strategy=1) # Float
ros = RandomOverSampler(sampling_strategy="not majority") # String
X_over, y_over = ros.fit_resample(X, y)

ax = y_over.value_counts().plot.pie(autopct='%.2f')
_ = ax.set_title("Over-sampling")

# %%
y_over.value_counts()
# Out:
# No     5174
# Yes    5174
# Name: Churn, dtype: int64

# %%
X_over
# Out:
#        customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0      7590-VHVEG  Female              0     Yes         No       1
# 1      5575-GNVDE    Male              0      No         No      34
# 2      3668-QPYBK    Male              0      No         No       2
# 3      7795-CFOCW    Male              0      No         No      45
# 4      9237-HQITU  Female              0      No         No       2
# ...           ...     ...            ...     ...        ...     ...
# 10343  3006-XIMLN  Female              0      No        Yes       2
# 10344  8821-XNHVZ  Female              0     Yes        Yes       1
# 10345  1075-BGWOH    Male              1     Yes         No      16
# 10346  0203-HHYIJ    Male              0      No         No      25
# 10347  8565-CLBZW    Male              0      No         No      24
#
#       PhoneService     MultipleLines InternetService       OnlineSecurity  \
# 0               No  No phone service             DSL                   No
# 1              Yes                No             DSL                  Yes
# 2              Yes                No             DSL                  Yes
# 3               No  No phone service             DSL                  Yes
# 4              Yes                No     Fiber optic                   No
# ...            ...               ...             ...                  ...
# 10343          Yes               Yes     Fiber optic                   No
# 10344          Yes                No     Fiber optic                   No
# 10345          Yes               Yes     Fiber optic                   No
# 10346          Yes               Yes              No  No internet service
# 10347          Yes               Yes     Fiber optic                   No
#
#               OnlineBackup     DeviceProtection          TechSupport  \
# 0                      Yes                   No                   No
# 1                       No                  Yes                   No
# 2                      Yes                   No                   No
# 3                       No                  Yes                  Yes
# 4                       No                   No                   No
# ...                    ...                  ...                  ...
# 10343                   No                   No                   No
# 10344                   No                   No                   No
# 10345                   No                  Yes                   No
# 10346  No internet service  No internet service  No internet service
# 10347                   No                  Yes                   No
#
#                StreamingTV      StreamingMovies        Contract  \
# 0                       No                   No  Month-to-month
# 1                       No                   No        One year
# 2                       No                   No  Month-to-month
# 3                       No                   No        One year
# 4                       No                   No  Month-to-month
# ...                    ...                  ...             ...
# 10343                  Yes                  Yes  Month-to-month
# 10344                  Yes                   No  Month-to-month
# 10345                  Yes                  Yes  Month-to-month
# 10346  No internet service  No internet service        One year
# 10347                  Yes                   No  Month-to-month
#
#       PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0                  Yes           Electronic check           29.85        29.85
# 1                   No               Mailed check           56.95       1889.5
# 2                  Yes               Mailed check           53.85       108.15
# 3                   No  Bank transfer (automatic)           42.30      1840.75
# 4                  Yes           Electronic check           70.70       151.65
# ...                ...                        ...             ...          ...
# 10343              Yes  Bank transfer (automatic)           94.20        193.8
# 10344              Yes               Mailed check           80.05        80.05
# 10345              Yes           Electronic check           98.75      1587.55
# 10346               No  Bank transfer (automatic)           25.30       676.35
# 10347              Yes               Mailed check           89.85      2165.05
#
# [10348 rows x 20 columns]

# %%
y_over
# Out:
# 0         No
# 1         No
# 2        Yes
# 3         No
# 4        Yes
#         ...
# 10343    Yes
# 10344    Yes
# 10345    Yes
# 10346    Yes
# 10347    Yes
# Name: Churn, Length: 10348, dtype: object
